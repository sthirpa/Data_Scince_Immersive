# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Regularization and Optimization for Neural Networks
#
# _Authors:_ Matt Brems, Tim Book, Justin Pounders
#
#
# ### Learning Objectives
#
# By the end of the lesson, students should be able to:
# - Explain how L1/L2, dropout, and early stopping regularization work and implement these methods in Keras
# - Implement methods for speeding up learning

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('../data/cell_phone_churn.csv')
data.head()
# Out:
#   state  account_length  area_code intl_plan vmail_plan  vmail_message  \
# 0    KS             128        415        no        yes             25
# 1    OH             107        415        no        yes             26
# 2    NJ             137        415        no         no              0
# 3    OH              84        408       yes         no              0
# 4    OK              75        415       yes         no              0
#
#    day_mins  day_calls  day_charge  eve_mins  eve_calls  eve_charge  \
# 0     265.1        110       45.07     197.4         99       16.78
# 1     161.6        123       27.47     195.5        103       16.62
# 2     243.4        114       41.38     121.2        110       10.30
# 3     299.4         71       50.90      61.9         88        5.26
# 4     166.7        113       28.34     148.3        122       12.61
#
#    night_mins  night_calls  night_charge  intl_mins  intl_calls  intl_charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    custserv_calls  churn
# 0               1  False
# 1               1  False
# 2               0  False
# 3               2  False
# 4               3  False

# %%
# Drop state column
# data = data.drop('state', axis=1)
# data = data.drop('area_code', axis=1)
data.drop(columns = ['state', 'area_code'], inplace = True)

# Binarize intil_plan and vmail_plan columns
# Many ways to binarize:
data['intl_plan'] = data['intl_plan'].map(lambda x: 1 if x=='yes' else 0)
data['vmail_plan'] = data['vmail_plan'].map(lambda x: 1 if x=='yes' else 0)

# data['intl_plan'] = data['intl_plan'].map({'yes': 1, 'no': 0})
# data['intl_plan'] = (data['intl_plan'] == 'yes').astype('int')
# data['intl_plan'] = (data['intl_plan'] == 'yes') * 1
# data['intl_plan'] = np.where(data['intl_plan'] == 'yes', 1, 0)

# %%
# Split into X and y
X = data.drop('churn', axis=1)
y = data['churn'].astype('int')

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# Scale data
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
1 - y.mean()
# Out:
# 0.8550855085508551

# %% [markdown]
# ## Build a simple neural net to model churn
#
# Let's build this:
#
# - a dense network,
# - one input layer,
# - one hidden layer
#   - slightly smaller than input layer
#   - ReLU activation
# - single node output (for binary classification)

# %% [markdown]
# <details><summary>What activation function will we use for our output layer here?</summary>
#
# - Sigmoid activation, since we are doing binary classification.
# </details>

# %% [markdown]
# > **Fun fact**: If we dropped the hidden layer, this model would just be logistic regression!  Can you prove that to yourself?

# %%
# Input shape
n_input = X_train_sc.shape[1]
# input_shape=(X_train_sc.shape[1], )
# input_dim=X_train_sc.shape[1]

# %%
n_input
# Out:
# 17

# %%
model = Sequential()
model.add(Dense(17, input_dim=n_input, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc']) # loss = 'bce'

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=None,
    verbose=2
)
# Out:
# Epoch 1/100
# 79/79 - 0s - loss: 0.4765 - acc: 0.8535 - val_loss: 0.4283 - val_acc: 0.8429
# Epoch 2/100
# 79/79 - 0s - loss: 0.3832 - acc: 0.8603 - val_loss: 0.3825 - val_acc: 0.8501
# Epoch 3/100
# 79/79 - 0s - loss: 0.3405 - acc: 0.8703 - val_loss: 0.3610 - val_acc: 0.8537
# Epoch 4/100
# 79/79 - 0s - loss: 0.3184 - acc: 0.8731 - val_loss: 0.3471 - val_acc: 0.8585
# Epoch 5/100
# 79/79 - 0s - loss: 0.3023 - acc: 0.8772 - val_loss: 0.3360 - val_acc: 0.8585
# Epoch 6/100
# 79/79 - 0s - loss: 0.2860 - acc: 0.8844 - val_loss: 0.3236 - val_acc: 0.8645
# Epoch 7/100
# 79/79 - 0s - loss: 0.2714 - acc: 0.8932 - val_loss: 0.3112 - val_acc: 0.8729
# Epoch 8/100
# 79/79 - 0s - loss: 0.2561 - acc: 0.9040 - val_loss: 0.3007 - val_acc: 0.8813
# Epoch 9/100
# 79/79 - 0s - loss: 0.2437 - acc: 0.9124 - val_loss: 0.2912 - val_acc: 0.8873
# Epoch 10/100
# 79/79 - 0s - loss: 0.2340 - acc: 0.9232 - val_loss: 0.2857 - val_acc: 0.8909
# Epoch 11/100
# 79/79 - 0s - loss: 0.2253 - acc: 0.9252 - val_loss: 0.2802 - val_acc: 0.8969
# Epoch 12/100
# 79/79 - 0s - loss: 0.2182 - acc: 0.9304 - val_loss: 0.2755 - val_acc: 0.9029
# Epoch 13/100
# 79/79 - 0s - loss: 0.2131 - acc: 0.9312 - val_loss: 0.2734 - val_acc: 0.9041
# Epoch 14/100
# 79/79 - 0s - loss: 0.2083 - acc: 0.9332 - val_loss: 0.2694 - val_acc: 0.9065
# Epoch 15/100
# 79/79 - 0s - loss: 0.2039 - acc: 0.9344 - val_loss: 0.2660 - val_acc: 0.9077
# Epoch 16/100
# 79/79 - 0s - loss: 0.2007 - acc: 0.9348 - val_loss: 0.2644 - val_acc: 0.9065
# Epoch 17/100
# 79/79 - 0s - loss: 0.1970 - acc: 0.9388 - val_loss: 0.2641 - val_acc: 0.9005
# Epoch 18/100
# 79/79 - 0s - loss: 0.1942 - acc: 0.9388 - val_loss: 0.2618 - val_acc: 0.8969
# Epoch 19/100
# 79/79 - 0s - loss: 0.1925 - acc: 0.9392 - val_loss: 0.2591 - val_acc: 0.9065
# Epoch 20/100
# 79/79 - 0s - loss: 0.1893 - acc: 0.9404 - val_loss: 0.2563 - val_acc: 0.9137
# Epoch 21/100
# 79/79 - 0s - loss: 0.1867 - acc: 0.9432 - val_loss: 0.2571 - val_acc: 0.9089
# Epoch 22/100
# 79/79 - 0s - loss: 0.1866 - acc: 0.9388 - val_loss: 0.2549 - val_acc: 0.9077
# Epoch 23/100
# 79/79 - 0s - loss: 0.1838 - acc: 0.9412 - val_loss: 0.2542 - val_acc: 0.9077
# Epoch 24/100
# 79/79 - 0s - loss: 0.1815 - acc: 0.9432 - val_loss: 0.2518 - val_acc: 0.9101
# Epoch 25/100
# 79/79 - 0s - loss: 0.1796 - acc: 0.9444 - val_loss: 0.2541 - val_acc: 0.9065
# Epoch 26/100
# 79/79 - 0s - loss: 0.1789 - acc: 0.9456 - val_loss: 0.2540 - val_acc: 0.9041
# Epoch 27/100
# 79/79 - 0s - loss: 0.1770 - acc: 0.9440 - val_loss: 0.2508 - val_acc: 0.9101
# Epoch 28/100
# 79/79 - 0s - loss: 0.1749 - acc: 0.9488 - val_loss: 0.2528 - val_acc: 0.9065
# Epoch 29/100
# 79/79 - 0s - loss: 0.1735 - acc: 0.9460 - val_loss: 0.2506 - val_acc: 0.9077
# Epoch 30/100
# 79/79 - 0s - loss: 0.1727 - acc: 0.9476 - val_loss: 0.2514 - val_acc: 0.9065
# Epoch 31/100
# 79/79 - 0s - loss: 0.1714 - acc: 0.9484 - val_loss: 0.2488 - val_acc: 0.9077
# Epoch 32/100
# 79/79 - 0s - loss: 0.1694 - acc: 0.9500 - val_loss: 0.2476 - val_acc: 0.9089
# Epoch 33/100
# 79/79 - 0s - loss: 0.1686 - acc: 0.9492 - val_loss: 0.2487 - val_acc: 0.9089
# Epoch 34/100
# 79/79 - 0s - loss: 0.1671 - acc: 0.9496 - val_loss: 0.2467 - val_acc: 0.9113
# Epoch 35/100
# 79/79 - 0s - loss: 0.1651 - acc: 0.9516 - val_loss: 0.2463 - val_acc: 0.9125
# Epoch 36/100
# 79/79 - 0s - loss: 0.1647 - acc: 0.9536 - val_loss: 0.2465 - val_acc: 0.9089
# Epoch 37/100
# 79/79 - 0s - loss: 0.1634 - acc: 0.9508 - val_loss: 0.2457 - val_acc: 0.9113
# Epoch 38/100
# 79/79 - 0s - loss: 0.1631 - acc: 0.9516 - val_loss: 0.2471 - val_acc: 0.9089
# Epoch 39/100
# 79/79 - 0s - loss: 0.1608 - acc: 0.9516 - val_loss: 0.2508 - val_acc: 0.9101
# Epoch 40/100
# 79/79 - 0s - loss: 0.1612 - acc: 0.9520 - val_loss: 0.2464 - val_acc: 0.9125
# Epoch 41/100
# 79/79 - 0s - loss: 0.1590 - acc: 0.9540 - val_loss: 0.2481 - val_acc: 0.9125
# Epoch 42/100
# 79/79 - 0s - loss: 0.1584 - acc: 0.9536 - val_loss: 0.2438 - val_acc: 0.9137
# Epoch 43/100
# 79/79 - 0s - loss: 0.1569 - acc: 0.9544 - val_loss: 0.2456 - val_acc: 0.9089
# Epoch 44/100
# 79/79 - 0s - loss: 0.1564 - acc: 0.9568 - val_loss: 0.2465 - val_acc: 0.9125
# Epoch 45/100
# 79/79 - 0s - loss: 0.1557 - acc: 0.9528 - val_loss: 0.2456 - val_acc: 0.9101
# Epoch 46/100
# 79/79 - 0s - loss: 0.1543 - acc: 0.9564 - val_loss: 0.2462 - val_acc: 0.9101
# Epoch 47/100
# 79/79 - 0s - loss: 0.1535 - acc: 0.9560 - val_loss: 0.2452 - val_acc: 0.9137
# Epoch 48/100
# 79/79 - 0s - loss: 0.1522 - acc: 0.9548 - val_loss: 0.2461 - val_acc: 0.9149
# Epoch 49/100
# 79/79 - 0s - loss: 0.1515 - acc: 0.9552 - val_loss: 0.2436 - val_acc: 0.9149
# Epoch 50/100
# 79/79 - 0s - loss: 0.1510 - acc: 0.9556 - val_loss: 0.2447 - val_acc: 0.9173
# Epoch 51/100
# 79/79 - 0s - loss: 0.1506 - acc: 0.9564 - val_loss: 0.2430 - val_acc: 0.9173
# Epoch 52/100
# 79/79 - 0s - loss: 0.1491 - acc: 0.9552 - val_loss: 0.2441 - val_acc: 0.9149
# Epoch 53/100
# 79/79 - 0s - loss: 0.1482 - acc: 0.9556 - val_loss: 0.2442 - val_acc: 0.9173
# Epoch 54/100
# 79/79 - 0s - loss: 0.1473 - acc: 0.9556 - val_loss: 0.2483 - val_acc: 0.9149
# Epoch 55/100
# 79/79 - 0s - loss: 0.1477 - acc: 0.9568 - val_loss: 0.2465 - val_acc: 0.9161
# Epoch 56/100
# 79/79 - 0s - loss: 0.1458 - acc: 0.9572 - val_loss: 0.2458 - val_acc: 0.9161
# Epoch 57/100
# 79/79 - 0s - loss: 0.1461 - acc: 0.9576 - val_loss: 0.2441 - val_acc: 0.9185
# Epoch 58/100
# 79/79 - 0s - loss: 0.1435 - acc: 0.9576 - val_loss: 0.2424 - val_acc: 0.9185
# Epoch 59/100
# 79/79 - 0s - loss: 0.1430 - acc: 0.9576 - val_loss: 0.2436 - val_acc: 0.9197
# Epoch 60/100
# 79/79 - 0s - loss: 0.1426 - acc: 0.9580 - val_loss: 0.2421 - val_acc: 0.9185
# Epoch 61/100
# 79/79 - 0s - loss: 0.1425 - acc: 0.9584 - val_loss: 0.2434 - val_acc: 0.9173
# Epoch 62/100
# 79/79 - 0s - loss: 0.1419 - acc: 0.9592 - val_loss: 0.2450 - val_acc: 0.9185
# Epoch 63/100
# 79/79 - 0s - loss: 0.1409 - acc: 0.9580 - val_loss: 0.2431 - val_acc: 0.9161
# Epoch 64/100
# 79/79 - 0s - loss: 0.1409 - acc: 0.9580 - val_loss: 0.2447 - val_acc: 0.9185
# Epoch 65/100
# 79/79 - 0s - loss: 0.1392 - acc: 0.9592 - val_loss: 0.2431 - val_acc: 0.9197
# Epoch 66/100
# 79/79 - 0s - loss: 0.1391 - acc: 0.9596 - val_loss: 0.2419 - val_acc: 0.9173
# Epoch 67/100
# 79/79 - 0s - loss: 0.1381 - acc: 0.9612 - val_loss: 0.2477 - val_acc: 0.9185
# Epoch 68/100
# 79/79 - 0s - loss: 0.1389 - acc: 0.9576 - val_loss: 0.2432 - val_acc: 0.9185
# Epoch 69/100
# 79/79 - 0s - loss: 0.1380 - acc: 0.9584 - val_loss: 0.2422 - val_acc: 0.9185
# Epoch 70/100
# 79/79 - 0s - loss: 0.1370 - acc: 0.9588 - val_loss: 0.2427 - val_acc: 0.9185
# Epoch 71/100
# 79/79 - 0s - loss: 0.1366 - acc: 0.9560 - val_loss: 0.2438 - val_acc: 0.9173
# Epoch 72/100
# 79/79 - 0s - loss: 0.1355 - acc: 0.9580 - val_loss: 0.2434 - val_acc: 0.9209
# Epoch 73/100
# 79/79 - 0s - loss: 0.1350 - acc: 0.9620 - val_loss: 0.2416 - val_acc: 0.9197
# Epoch 74/100
# 79/79 - 0s - loss: 0.1344 - acc: 0.9596 - val_loss: 0.2405 - val_acc: 0.9233
# Epoch 75/100
# 79/79 - 0s - loss: 0.1340 - acc: 0.9608 - val_loss: 0.2444 - val_acc: 0.9197
# Epoch 76/100
# 79/79 - 0s - loss: 0.1335 - acc: 0.9592 - val_loss: 0.2416 - val_acc: 0.9185
# Epoch 77/100
# 79/79 - 0s - loss: 0.1327 - acc: 0.9600 - val_loss: 0.2421 - val_acc: 0.9209
# Epoch 78/100
# 79/79 - 0s - loss: 0.1326 - acc: 0.9608 - val_loss: 0.2418 - val_acc: 0.9221
# Epoch 79/100
# 79/79 - 0s - loss: 0.1326 - acc: 0.9600 - val_loss: 0.2453 - val_acc: 0.9161
# Epoch 80/100
# 79/79 - 0s - loss: 0.1320 - acc: 0.9608 - val_loss: 0.2408 - val_acc: 0.9233
# Epoch 81/100
# 79/79 - 0s - loss: 0.1309 - acc: 0.9604 - val_loss: 0.2416 - val_acc: 0.9209
# Epoch 82/100
# 79/79 - 0s - loss: 0.1307 - acc: 0.9612 - val_loss: 0.2420 - val_acc: 0.9197
# Epoch 83/100
# 79/79 - 0s - loss: 0.1331 - acc: 0.9600 - val_loss: 0.2453 - val_acc: 0.9233
# Epoch 84/100
# 79/79 - 0s - loss: 0.1295 - acc: 0.9600 - val_loss: 0.2459 - val_acc: 0.9233
# Epoch 85/100
# 79/79 - 0s - loss: 0.1287 - acc: 0.9628 - val_loss: 0.2436 - val_acc: 0.9233
# Epoch 86/100
# 79/79 - 0s - loss: 0.1279 - acc: 0.9624 - val_loss: 0.2429 - val_acc: 0.9245
# Epoch 87/100
# 79/79 - 0s - loss: 0.1279 - acc: 0.9620 - val_loss: 0.2419 - val_acc: 0.9245
# Epoch 88/100
# 79/79 - 0s - loss: 0.1266 - acc: 0.9632 - val_loss: 0.2425 - val_acc: 0.9257
# Epoch 89/100
# 79/79 - 0s - loss: 0.1254 - acc: 0.9640 - val_loss: 0.2413 - val_acc: 0.9233
# Epoch 90/100
# 79/79 - 0s - loss: 0.1252 - acc: 0.9628 - val_loss: 0.2440 - val_acc: 0.9209
# Epoch 91/100
# 79/79 - 0s - loss: 0.1247 - acc: 0.9628 - val_loss: 0.2412 - val_acc: 0.9245
# Epoch 92/100
# 79/79 - 0s - loss: 0.1253 - acc: 0.9628 - val_loss: 0.2431 - val_acc: 0.9269
# Epoch 93/100
# 79/79 - 0s - loss: 0.1238 - acc: 0.9632 - val_loss: 0.2415 - val_acc: 0.9221
# Epoch 94/100
# 79/79 - 0s - loss: 0.1232 - acc: 0.9640 - val_loss: 0.2413 - val_acc: 0.9233
# Epoch 95/100
# 79/79 - 0s - loss: 0.1223 - acc: 0.9644 - val_loss: 0.2424 - val_acc: 0.9257
# Epoch 96/100
# 79/79 - 0s - loss: 0.1232 - acc: 0.9652 - val_loss: 0.2422 - val_acc: 0.9221
# Epoch 97/100
# 79/79 - 0s - loss: 0.1215 - acc: 0.9652 - val_loss: 0.2426 - val_acc: 0.9257
# Epoch 98/100
# 79/79 - 0s - loss: 0.1218 - acc: 0.9656 - val_loss: 0.2414 - val_acc: 0.9269
# Epoch 99/100
# 79/79 - 0s - loss: 0.1204 - acc: 0.9664 - val_loss: 0.2417 - val_acc: 0.9269
# Epoch 100/100
# 79/79 - 0s - loss: 0.1210 - acc: 0.9632 - val_loss: 0.2469 - val_acc: 0.9233

# %%
train_loss = history.history['loss']
test_loss = history.history['val_loss']

plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.legend();

# %%
history.history['acc'][-1], history.history['val_acc'][-1]
# Out:
# (0.9631852507591248, 0.9232614040374756)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 17)                306
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                180
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ![](../assets/overkill.jpg)

# %% [markdown]
# <a id='l1'></a>
# ## Regularization Method 1: $\mathcal{l}_1$ and $\mathcal{l}_2$
# ---
# Just as we did with linear models, we can use $\mathcal{l}_1$ (LASSO) and $\mathcal{l}_2$ (Ridge) regularization on our neural networks.
#
# Recall from our notation:
#
# * $J(\theta) = L(\mathbf{y}, \hat{\mathbf{y}})$ is the value of the loss function with respect to...
# * $\theta$, the list of _all_ model coefficients (all weights and biases).
#
# We regularize our neural networks by adding a penalty term to our loss function:
#
# $$ \text{minimize } J(\theta) + \lambda \|\theta\|_2^2 $$
#
# This has the effect of penalizing our parameters $\theta$ by shrinking them, hence bartering in the bias-variance tradeoff by (hopefully) reducing variance by adding bias. Although it is rarely done, **Keras actually gives us the opportunity to penalize the weights at different layers by different amounts.**
#
# ## Which to pick: $\mathcal{l}_1$ or $\mathcal{l}_2$?
# Recall the key difference: $\mathcal{l}_1$ penalties perform _selection_. That is, they often zero out parameters when they're small enough. While this sounds appealing, $\mathcal{l}_2$ is used almost exclusively. It's done so often, that deep learning practitions give it a special name: **weight decay**.

# %%
# from tensorflow.keras import regularizers
from tensorflow.keras.regularizers import l2

model_l2 = Sequential()

n_input = X_train.shape[1]

model_l2.add(Dense(
    17,
    input_dim=n_input,
    activation='relu',
    kernel_regularizer=l2(0.001)
))

model_l2.add(Dense(
    10,
    activation='sigmoid',
    kernel_regularizer=l2(0.001)
))

model_l2.add(Dense(
    1,
    activation='sigmoid',
    kernel_regularizer=l2(0.001)
))

model_l2.compile(
    loss='bce',
    optimizer='adam',
    metrics=['acc']
)

history_l2 = model_l2.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=None
)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5289 - acc: 0.8587 - val_loss: 0.4836 - val_acc: 0.8429
# Epoch 2/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.4416 - acc: 0.8591 - val_loss: 0.4483 - val_acc: 0.8429
# Epoch 3/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.4121 - acc: 0.8591 - val_loss: 0.4313 - val_acc: 0.8429
# Epoch 4/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3940 - acc: 0.8591 - val_loss: 0.4166 - val_acc: 0.8429
# Epoch 5/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3779 - acc: 0.8591 - val_loss: 0.4039 - val_acc: 0.8453
# Epoch 6/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3652 - acc: 0.8611 - val_loss: 0.3940 - val_acc: 0.8513
# Epoch 7/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3558 - acc: 0.8647 - val_loss: 0.3871 - val_acc: 0.8525
# Epoch 8/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3486 - acc: 0.8723 - val_loss: 0.3816 - val_acc: 0.8513
# Epoch 9/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3432 - acc: 0.8752 - val_loss: 0.3784 - val_acc: 0.8513
# Epoch 10/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3387 - acc: 0.8772 - val_loss: 0.3752 - val_acc: 0.8549
# Epoch 11/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3345 - acc: 0.8756 - val_loss: 0.3711 - val_acc: 0.8525
# Epoch 12/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3297 - acc: 0.8756 - val_loss: 0.3669 - val_acc: 0.8513
# Epoch 13/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3246 - acc: 0.8776 - val_loss: 0.3639 - val_acc: 0.8561
# Epoch 14/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3186 - acc: 0.8796 - val_loss: 0.3576 - val_acc: 0.8537
# Epoch 15/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3120 - acc: 0.8816 - val_loss: 0.3519 - val_acc: 0.8573
# Epoch 16/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3053 - acc: 0.8828 - val_loss: 0.3470 - val_acc: 0.8573
# Epoch 17/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2990 - acc: 0.8876 - val_loss: 0.3419 - val_acc: 0.8573
# Epoch 18/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2931 - acc: 0.8916 - val_loss: 0.3366 - val_acc: 0.8657
# Epoch 19/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2872 - acc: 0.8932 - val_loss: 0.3331 - val_acc: 0.8669
# Epoch 20/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2819 - acc: 0.9000 - val_loss: 0.3288 - val_acc: 0.8717
# Epoch 21/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2773 - acc: 0.8992 - val_loss: 0.3242 - val_acc: 0.8813
# Epoch 22/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2727 - acc: 0.9032 - val_loss: 0.3195 - val_acc: 0.8837
# Epoch 23/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2688 - acc: 0.9048 - val_loss: 0.3166 - val_acc: 0.8861
# Epoch 24/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2666 - acc: 0.9096 - val_loss: 0.3165 - val_acc: 0.8861
# Epoch 25/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2626 - acc: 0.9116 - val_loss: 0.3131 - val_acc: 0.8909
# Epoch 26/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2602 - acc: 0.9128 - val_loss: 0.3104 - val_acc: 0.8909
# Epoch 27/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2577 - acc: 0.9156 - val_loss: 0.3093 - val_acc: 0.8909
# Epoch 28/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2561 - acc: 0.9200 - val_loss: 0.3086 - val_acc: 0.8897
# Epoch 29/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2542 - acc: 0.9188 - val_loss: 0.3052 - val_acc: 0.8909
# Epoch 30/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2525 - acc: 0.9204 - val_loss: 0.3048 - val_acc: 0.8921
# Epoch 31/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2513 - acc: 0.9220 - val_loss: 0.3051 - val_acc: 0.8909
# Epoch 32/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2500 - acc: 0.9228 - val_loss: 0.3037 - val_acc: 0.8909
# Epoch 33/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2483 - acc: 0.9244 - val_loss: 0.3023 - val_acc: 0.8933
# Epoch 34/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2481 - acc: 0.9260 - val_loss: 0.3019 - val_acc: 0.8945
# Epoch 35/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2484 - acc: 0.9288 - val_loss: 0.3024 - val_acc: 0.8981
# Epoch 36/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2460 - acc: 0.9268 - val_loss: 0.2973 - val_acc: 0.9005
# Epoch 37/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2448 - acc: 0.9304 - val_loss: 0.2982 - val_acc: 0.8993
# Epoch 38/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2439 - acc: 0.9300 - val_loss: 0.2987 - val_acc: 0.8981
# Epoch 39/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2432 - acc: 0.9324 - val_loss: 0.2976 - val_acc: 0.9005
# Epoch 40/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2423 - acc: 0.9296 - val_loss: 0.2979 - val_acc: 0.9005
# Epoch 41/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2416 - acc: 0.9312 - val_loss: 0.2973 - val_acc: 0.8993
# Epoch 42/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2411 - acc: 0.9352 - val_loss: 0.2982 - val_acc: 0.8993
# Epoch 43/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2412 - acc: 0.9324 - val_loss: 0.2961 - val_acc: 0.9041
# Epoch 44/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2404 - acc: 0.9364 - val_loss: 0.2958 - val_acc: 0.9017
# Epoch 45/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2395 - acc: 0.9352 - val_loss: 0.2950 - val_acc: 0.9017
# Epoch 46/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2392 - acc: 0.9348 - val_loss: 0.2940 - val_acc: 0.9005
# Epoch 47/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2388 - acc: 0.9360 - val_loss: 0.2957 - val_acc: 0.9017
# Epoch 48/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2383 - acc: 0.9320 - val_loss: 0.2943 - val_acc: 0.9017
# Epoch 49/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2379 - acc: 0.9368 - val_loss: 0.2928 - val_acc: 0.9041
# Epoch 50/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2374 - acc: 0.9356 - val_loss: 0.2924 - val_acc: 0.9005
# Epoch 51/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2369 - acc: 0.9380 - val_loss: 0.2932 - val_acc: 0.9041
# Epoch 52/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2368 - acc: 0.9364 - val_loss: 0.2922 - val_acc: 0.9041
# Epoch 53/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2359 - acc: 0.9356 - val_loss: 0.2917 - val_acc: 0.9029
# Epoch 54/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2355 - acc: 0.9392 - val_loss: 0.2945 - val_acc: 0.9041
# Epoch 55/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2356 - acc: 0.9364 - val_loss: 0.2927 - val_acc: 0.9041
# Epoch 56/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2350 - acc: 0.9388 - val_loss: 0.2917 - val_acc: 0.9053
# Epoch 57/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2349 - acc: 0.9380 - val_loss: 0.2906 - val_acc: 0.9065
# Epoch 58/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2350 - acc: 0.9404 - val_loss: 0.2925 - val_acc: 0.9017
# Epoch 59/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2341 - acc: 0.9392 - val_loss: 0.2911 - val_acc: 0.9029
# Epoch 60/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2339 - acc: 0.9400 - val_loss: 0.2922 - val_acc: 0.9053
# Epoch 61/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2334 - acc: 0.9392 - val_loss: 0.2913 - val_acc: 0.9041
# Epoch 62/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2333 - acc: 0.9412 - val_loss: 0.2914 - val_acc: 0.9065
# Epoch 63/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2333 - acc: 0.9392 - val_loss: 0.2899 - val_acc: 0.9089
# Epoch 64/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2325 - acc: 0.9392 - val_loss: 0.2904 - val_acc: 0.9077
# Epoch 65/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2334 - acc: 0.9400 - val_loss: 0.2923 - val_acc: 0.9017
# Epoch 66/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2327 - acc: 0.9416 - val_loss: 0.2924 - val_acc: 0.9053
# Epoch 67/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2318 - acc: 0.9404 - val_loss: 0.2893 - val_acc: 0.9089
# Epoch 68/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2315 - acc: 0.9416 - val_loss: 0.2911 - val_acc: 0.9053
# Epoch 69/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2317 - acc: 0.9404 - val_loss: 0.2890 - val_acc: 0.9077
# Epoch 70/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2312 - acc: 0.9396 - val_loss: 0.2890 - val_acc: 0.9065
# Epoch 71/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2309 - acc: 0.9420 - val_loss: 0.2916 - val_acc: 0.9041
# Epoch 72/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2311 - acc: 0.9420 - val_loss: 0.2907 - val_acc: 0.9053
# Epoch 73/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2311 - acc: 0.9400 - val_loss: 0.2892 - val_acc: 0.9053
# Epoch 74/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2302 - acc: 0.9436 - val_loss: 0.2900 - val_acc: 0.9029
# Epoch 75/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2306 - acc: 0.9404 - val_loss: 0.2876 - val_acc: 0.9089
# Epoch 76/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2299 - acc: 0.9420 - val_loss: 0.2880 - val_acc: 0.9065
# Epoch 77/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2306 - acc: 0.9436 - val_loss: 0.2900 - val_acc: 0.9029
# Epoch 78/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2298 - acc: 0.9424 - val_loss: 0.2887 - val_acc: 0.9053
# Epoch 79/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2292 - acc: 0.9428 - val_loss: 0.2864 - val_acc: 0.9077
# Epoch 80/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2295 - acc: 0.9428 - val_loss: 0.2889 - val_acc: 0.9053
# Epoch 81/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2291 - acc: 0.9440 - val_loss: 0.2873 - val_acc: 0.9053
# Epoch 82/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2293 - acc: 0.9456 - val_loss: 0.2873 - val_acc: 0.9065
# Epoch 83/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2288 - acc: 0.9448 - val_loss: 0.2875 - val_acc: 0.9077
# Epoch 84/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2288 - acc: 0.9420 - val_loss: 0.2883 - val_acc: 0.9041
# Epoch 85/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2283 - acc: 0.9436 - val_loss: 0.2866 - val_acc: 0.9065
# Epoch 86/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2284 - acc: 0.9436 - val_loss: 0.2869 - val_acc: 0.9053
# Epoch 87/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2288 - acc: 0.9436 - val_loss: 0.2878 - val_acc: 0.9053
# Epoch 88/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2277 - acc: 0.9444 - val_loss: 0.2851 - val_acc: 0.9089
# Epoch 89/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2275 - acc: 0.9448 - val_loss: 0.2881 - val_acc: 0.9041
# Epoch 90/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2277 - acc: 0.9448 - val_loss: 0.2858 - val_acc: 0.9053
# Epoch 91/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2277 - acc: 0.9432 - val_loss: 0.2835 - val_acc: 0.9089
# Epoch 92/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2267 - acc: 0.9440 - val_loss: 0.2844 - val_acc: 0.9077
# Epoch 93/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2269 - acc: 0.9468 - val_loss: 0.2846 - val_acc: 0.9089
# Epoch 94/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2273 - acc: 0.9432 - val_loss: 0.2845 - val_acc: 0.9101
# Epoch 95/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2281 - acc: 0.9452 - val_loss: 0.2856 - val_acc: 0.9053
# Epoch 96/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2271 - acc: 0.9444 - val_loss: 0.2849 - val_acc: 0.9077
# Epoch 97/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2264 - acc: 0.9448 - val_loss: 0.2843 - val_acc: 0.9089
# Epoch 98/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2261 - acc: 0.9452 - val_loss: 0.2852 - val_acc: 0.9065
# Epoch 99/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2264 - acc: 0.9436 - val_loss: 0.2831 - val_acc: 0.9065
# Epoch 100/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2263 - acc: 0.9452 - val_loss: 0.2830 - val_acc: 0.9065

# %%
train_loss_l2 = history_l2.history['loss']
test_loss_l2 = history_l2.history['val_loss']

plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.plot(train_loss_l2, label='L2 Training loss', color='darkred')
plt.plot(test_loss_l2, label='L2 Testing loss', color='pink')
plt.legend();

# %%
history_l2.history['acc'][-1], history_l2.history['val_acc'][-1]
# Out:
# (0.9451780915260315, 0.9064748287200928)

# %% [markdown]
# ## Keras Resources
# - [Keras Regularization Documentation](https://keras.io/regularizers/)
# - [Kernel vs. Activity Regularizers](https://github.com/keras-team/keras/issues/3236)
#
# ## Tensorflow Resources
# - [Implementation in Tensorflow](https://www.tensorflow.org/versions/r0.12/api_docs/python/contrib.layers/regularizers)
# - [Example in Tensorflow](http://www.ritchieng.com/machine-learning/deep-learning/tensorflow/regularization/)

# %% [markdown]
# <a id='dropout'></a>
# ## Regularization Method 2: Dropout
# ---
# There's another method of regularizing our terms that is specifically designed for neural networks, called **dropout regularization.**

# %% [markdown]
# Let's say we've constructed a neural network. We've decided on the number of layers we want and the number of nodes in each layer. (We might say that we've decided on the **topology** or **structure** of our network.)
#
# ![](../assets/original_nn.jpeg)
#
# However, a densely connected network like this will almost certainly overfit. Our network is learning a parameter for every single connection.
#
# > In the above example, we have 55 parameters being learned - and this is a very simple network, all things considered.
#
# > We can overcome this by using **dropout regularization**.
#
# In dropout regularization, we randomly **drop** units (nodes) in our neural network ***during our training phase only***. We assign a probability of each node disappearing. Then, we essentially perform a coinflip for every node to turn that node "on" or "off."
#
# Let's go through an example to illustrate this: For simplicity, we'll say we've assigned a 0.5 probability of keeping to every node in the network above. Then, for every node, we flip a coin, and if the coin lands on heads, the node remains, if it lands on tails, the node disappears. After we've done this for every node, we're left with a new network that looks something like this:
#
# ![](../assets/after_dropout.jpeg)
#
# <!--
# Image sources: https://pgaleone.eu/deep-learning/regularization/2017/01/10/anaysis-of-dropout/
# Also, it seems, this site: http://cs231n.github.io/neural-networks-2/
# -->
#
# Let's explicitly lay out the general workflow you would follow:
#
# 1. Specify the topology of your neural network.
# 2. Initialize your weights and biases.
# 3. Specify the "keeping probabilities" for every node. (Generally, we'll assign the same probability to all nodes in each layer and usually the same probability to all hidden layers.)
# 4. Perform a "coin flip" for each node and drop out the chosen nodes.
# 5. Run through one epoch of training.
# 6. Repeat steps 4 and 5 for each epoch of training.

# %% [markdown]
# ![](https://cdn.analyticsvidhya.com/wp-content/uploads/2018/04/1IrdJ5PghD9YoOyVAQ73MJw.gif)

# %% [markdown]
# <details><summary>If I drop out a node during one of my epochs, does it disappear from my final network?</summary>
#
# - No!
# </details>

# %% [markdown]
# #### So, what does this do?
# <!-- <br/> -->
# The intuition behind dropout is that, since each node has a probability of disappearing at any time, the neural network is disincentivized from allocating too much power to any one weight. It has a similar effect as imposing an L2 penalty: the magnitude of our weights shrinks.

# %% [markdown]
# <details><summary>What might be some potential problems with doing this?</summary>
#
# - expected values of nodes changes
# - induces bias
# </details>

# %% [markdown]
# So we've now run through every epoch of our training phase and we're ready to apply our neural network to our validation or testing data.
#
# <details><summary>Are we going to apply dropout to this data as well?</summary>
#
# - No!
# </details>

# %% [markdown]
# #### Best practices:
#
# - Don't set any keeping probabilities for layers you where you don't want to drop any nodes.
#
# <details><summary>What might be examples of these layers?</summary>
#
# - Input layers
# - Output layers
# </details>

# %% [markdown]
# - You'll generally want to specify a single keeping probability and all the layers on which you want to apply dropout, instead of specifying different keeping probabilities for each layer.

# %%
from tensorflow.keras.layers import Dropout

model_dropout = Sequential()

n_input = X_train.shape[1]
n_hidden = n_input

model_dropout.add(Dense(n_hidden, input_dim=n_input, activation='relu'))
model_dropout.add(Dropout(0.2)) # refers to nodes in the first hidden layer
model_dropout.add(Dense(10, activation='relu'))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(1, activation='sigmoid'))

model_dropout.compile(loss='bce', optimizer='adam', metrics=['acc'])

history_dropout = model_dropout.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test), 
    epochs=100,
    batch_size=None
)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6406 - acc: 0.6174 - val_loss: 0.5263 - val_acc: 0.8153
# Epoch 2/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.5051 - acc: 0.8135 - val_loss: 0.4548 - val_acc: 0.8429
# Epoch 3/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.4317 - acc: 0.8435 - val_loss: 0.4159 - val_acc: 0.8441
# Epoch 4/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.4090 - acc: 0.8499 - val_loss: 0.3911 - val_acc: 0.8441
# Epoch 5/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3881 - acc: 0.8511 - val_loss: 0.3751 - val_acc: 0.8453
# Epoch 6/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3708 - acc: 0.8583 - val_loss: 0.3626 - val_acc: 0.8525
# Epoch 7/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3672 - acc: 0.8647 - val_loss: 0.3541 - val_acc: 0.8489
# Epoch 8/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3581 - acc: 0.8655 - val_loss: 0.3484 - val_acc: 0.8465
# Epoch 9/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3432 - acc: 0.8567 - val_loss: 0.3372 - val_acc: 0.8465
# Epoch 10/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3364 - acc: 0.8631 - val_loss: 0.3307 - val_acc: 0.8465
# Epoch 11/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3244 - acc: 0.8679 - val_loss: 0.3251 - val_acc: 0.8489
# Epoch 12/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3173 - acc: 0.8687 - val_loss: 0.3186 - val_acc: 0.8513
# Epoch 13/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3146 - acc: 0.8663 - val_loss: 0.3149 - val_acc: 0.8549
# Epoch 14/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3129 - acc: 0.8691 - val_loss: 0.3119 - val_acc: 0.8561
# Epoch 15/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3076 - acc: 0.8719 - val_loss: 0.3085 - val_acc: 0.8561
# Epoch 16/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2973 - acc: 0.8824 - val_loss: 0.3028 - val_acc: 0.8561
# Epoch 17/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2883 - acc: 0.8900 - val_loss: 0.2953 - val_acc: 0.8645
# Epoch 18/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2872 - acc: 0.8988 - val_loss: 0.2880 - val_acc: 0.8741
# Epoch 19/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2884 - acc: 0.8960 - val_loss: 0.2835 - val_acc: 0.8765
# Epoch 20/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2814 - acc: 0.9000 - val_loss: 0.2801 - val_acc: 0.8825
# Epoch 21/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2745 - acc: 0.9032 - val_loss: 0.2764 - val_acc: 0.8849
# Epoch 22/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2775 - acc: 0.9024 - val_loss: 0.2737 - val_acc: 0.8849
# Epoch 23/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2682 - acc: 0.8992 - val_loss: 0.2736 - val_acc: 0.8873
# Epoch 24/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2648 - acc: 0.9048 - val_loss: 0.2692 - val_acc: 0.8909
# Epoch 25/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2656 - acc: 0.9084 - val_loss: 0.2681 - val_acc: 0.8897
# Epoch 26/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2643 - acc: 0.9080 - val_loss: 0.2668 - val_acc: 0.8909
# Epoch 27/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2647 - acc: 0.9044 - val_loss: 0.2637 - val_acc: 0.8933
# Epoch 28/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2612 - acc: 0.9112 - val_loss: 0.2628 - val_acc: 0.8969
# Epoch 29/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2545 - acc: 0.9148 - val_loss: 0.2598 - val_acc: 0.9017
# Epoch 30/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2441 - acc: 0.9156 - val_loss: 0.2578 - val_acc: 0.8957
# Epoch 31/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2469 - acc: 0.9156 - val_loss: 0.2554 - val_acc: 0.8981
# Epoch 32/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2533 - acc: 0.9120 - val_loss: 0.2599 - val_acc: 0.8957
# Epoch 33/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2493 - acc: 0.9112 - val_loss: 0.2554 - val_acc: 0.8993
# Epoch 34/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2452 - acc: 0.9124 - val_loss: 0.2548 - val_acc: 0.8981
# Epoch 35/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2465 - acc: 0.9160 - val_loss: 0.2535 - val_acc: 0.9005
# Epoch 36/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2515 - acc: 0.9108 - val_loss: 0.2512 - val_acc: 0.9053
# Epoch 37/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2408 - acc: 0.9200 - val_loss: 0.2503 - val_acc: 0.9065
# Epoch 38/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2389 - acc: 0.9212 - val_loss: 0.2506 - val_acc: 0.9041
# Epoch 39/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2382 - acc: 0.9212 - val_loss: 0.2487 - val_acc: 0.9041
# Epoch 40/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2323 - acc: 0.9208 - val_loss: 0.2441 - val_acc: 0.9065
# Epoch 41/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2282 - acc: 0.9328 - val_loss: 0.2472 - val_acc: 0.9041
# Epoch 42/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2442 - acc: 0.9136 - val_loss: 0.2506 - val_acc: 0.9041
# Epoch 43/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2276 - acc: 0.9196 - val_loss: 0.2444 - val_acc: 0.9065
# Epoch 44/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2330 - acc: 0.9188 - val_loss: 0.2447 - val_acc: 0.9065
# Epoch 45/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2255 - acc: 0.9216 - val_loss: 0.2424 - val_acc: 0.9077
# Epoch 46/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2276 - acc: 0.9220 - val_loss: 0.2448 - val_acc: 0.9065
# Epoch 47/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2277 - acc: 0.9232 - val_loss: 0.2416 - val_acc: 0.9089
# Epoch 48/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2180 - acc: 0.9212 - val_loss: 0.2386 - val_acc: 0.9113
# Epoch 49/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2295 - acc: 0.9196 - val_loss: 0.2415 - val_acc: 0.9065
# Epoch 50/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2302 - acc: 0.9268 - val_loss: 0.2412 - val_acc: 0.9077
# Epoch 51/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2269 - acc: 0.9220 - val_loss: 0.2386 - val_acc: 0.9101
# Epoch 52/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2238 - acc: 0.9224 - val_loss: 0.2391 - val_acc: 0.9077
# Epoch 53/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2210 - acc: 0.9212 - val_loss: 0.2375 - val_acc: 0.9065
# Epoch 54/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2203 - acc: 0.9256 - val_loss: 0.2379 - val_acc: 0.9101
# Epoch 55/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2234 - acc: 0.9256 - val_loss: 0.2364 - val_acc: 0.9089
# Epoch 56/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2234 - acc: 0.9236 - val_loss: 0.2352 - val_acc: 0.9089
# Epoch 57/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2242 - acc: 0.9244 - val_loss: 0.2328 - val_acc: 0.9137
# Epoch 58/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2161 - acc: 0.9236 - val_loss: 0.2346 - val_acc: 0.9149
# Epoch 59/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2117 - acc: 0.9328 - val_loss: 0.2351 - val_acc: 0.9137
# Epoch 60/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2245 - acc: 0.9268 - val_loss: 0.2349 - val_acc: 0.9113
# Epoch 61/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2197 - acc: 0.9312 - val_loss: 0.2328 - val_acc: 0.9137
# Epoch 62/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2124 - acc: 0.9268 - val_loss: 0.2351 - val_acc: 0.9113
# Epoch 63/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2065 - acc: 0.9328 - val_loss: 0.2342 - val_acc: 0.9101
# Epoch 64/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2222 - acc: 0.9260 - val_loss: 0.2335 - val_acc: 0.9101
# Epoch 65/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2257 - acc: 0.9248 - val_loss: 0.2346 - val_acc: 0.9149
# Epoch 66/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2146 - acc: 0.9232 - val_loss: 0.2310 - val_acc: 0.9161
# Epoch 67/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2174 - acc: 0.9304 - val_loss: 0.2287 - val_acc: 0.9173
# Epoch 68/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2044 - acc: 0.9312 - val_loss: 0.2291 - val_acc: 0.9197
# Epoch 69/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2083 - acc: 0.9316 - val_loss: 0.2288 - val_acc: 0.9161
# Epoch 70/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2111 - acc: 0.9328 - val_loss: 0.2283 - val_acc: 0.9173
# Epoch 71/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2108 - acc: 0.9340 - val_loss: 0.2275 - val_acc: 0.9161
# Epoch 72/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2013 - acc: 0.9360 - val_loss: 0.2290 - val_acc: 0.9137
# Epoch 73/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2037 - acc: 0.9288 - val_loss: 0.2287 - val_acc: 0.9149
# Epoch 74/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2094 - acc: 0.9284 - val_loss: 0.2279 - val_acc: 0.9161
# Epoch 75/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2187 - acc: 0.9276 - val_loss: 0.2271 - val_acc: 0.9149
# Epoch 76/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2096 - acc: 0.9328 - val_loss: 0.2267 - val_acc: 0.9185
# Epoch 77/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2077 - acc: 0.9328 - val_loss: 0.2275 - val_acc: 0.9173
# Epoch 78/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1995 - acc: 0.9376 - val_loss: 0.2255 - val_acc: 0.9197
# Epoch 79/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2041 - acc: 0.9332 - val_loss: 0.2247 - val_acc: 0.9197
# Epoch 80/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1907 - acc: 0.9360 - val_loss: 0.2232 - val_acc: 0.9173
# Epoch 81/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2062 - acc: 0.9348 - val_loss: 0.2260 - val_acc: 0.9149
# Epoch 82/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2074 - acc: 0.9300 - val_loss: 0.2257 - val_acc: 0.9149
# Epoch 83/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2021 - acc: 0.9364 - val_loss: 0.2259 - val_acc: 0.9173
# Epoch 84/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1992 - acc: 0.9388 - val_loss: 0.2219 - val_acc: 0.9233
# Epoch 85/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2008 - acc: 0.9348 - val_loss: 0.2253 - val_acc: 0.9185
# Epoch 86/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1923 - acc: 0.9388 - val_loss: 0.2232 - val_acc: 0.9197
# Epoch 87/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2013 - acc: 0.9360 - val_loss: 0.2261 - val_acc: 0.9161
# Epoch 88/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1957 - acc: 0.9360 - val_loss: 0.2243 - val_acc: 0.9209
# Epoch 89/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2016 - acc: 0.9352 - val_loss: 0.2262 - val_acc: 0.9173
# Epoch 90/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1962 - acc: 0.9408 - val_loss: 0.2228 - val_acc: 0.9209
# Epoch 91/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1976 - acc: 0.9368 - val_loss: 0.2231 - val_acc: 0.9161
# Epoch 92/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2051 - acc: 0.9360 - val_loss: 0.2214 - val_acc: 0.9197
# Epoch 93/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2029 - acc: 0.9324 - val_loss: 0.2262 - val_acc: 0.9185
# Epoch 94/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1959 - acc: 0.9348 - val_loss: 0.2234 - val_acc: 0.9209
# Epoch 95/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1904 - acc: 0.9388 - val_loss: 0.2244 - val_acc: 0.9221
# Epoch 96/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2050 - acc: 0.9372 - val_loss: 0.2230 - val_acc: 0.9209
# Epoch 97/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1888 - acc: 0.9356 - val_loss: 0.2196 - val_acc: 0.9221
# Epoch 98/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1975 - acc: 0.9328 - val_loss: 0.2217 - val_acc: 0.9221
# Epoch 99/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1905 - acc: 0.9384 - val_loss: 0.2225 - val_acc: 0.9197
# Epoch 100/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1893 - acc: 0.9348 - val_loss: 0.2192 - val_acc: 0.9245

# %%
# Visualize loss
train_loss_dropout = history_dropout.history['loss']
test_loss_dropout = history_dropout.history['val_loss']

plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.plot(train_loss_dropout, label='Dropout Training loss', color='darkgreen')
plt.plot(test_loss_dropout, label='Dropout Testing loss', color='lightgreen')
plt.legend();

# %%
history_dropout.history['acc'][-1], history_dropout.history['val_acc'][-1]
# Out:
# (0.9347739219665527, 0.9244604110717773)

# %% [markdown]
# ## Keras Resources
# - [Keras Dropout Documentation](https://keras.io/layers/core/#dropout)
#
# ## Tensorflow Resources
# - [Tensorflow documentation](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)
# - [List of examples in Tensorflow](https://programtalk.com/python-examples/tensorflow.nn.dropout/)

# %% [markdown]
# ### Deep Learning week is also Memes week!
# ![](../assets/thanos-dropout.png)

# %% [markdown]
# <a id='stopping'></a>
# ## Regularization Method 3: Early Stopping
# ---
# The third method of regularization that we'll discuss today is called early stopping.
# </br>
# If we run though all our epochs of training and plot both our training and validation error, we'll typically see something like this:
#
# ![](../assets/train-val-error-reduced.png)
# *source*: [Prechelt, 1997](http://page.mi.fu-berlin.de/prechelt/Biblio/stop_tricks1997.pdf)

# %% [markdown]
# <details><summary>What is happening in this plot?</summary>
#
# - The Validation error begins to increase after a certain number of epochs!
# </details>

# %% [markdown]
# Early stopping does exactly what its name implies: it stop the training process early. Instead of continuing training through every epoch, once the validation error begins to increase, our algorithm stops because it has (in theory) found the minimum for the validation loss.
#
# This might seem like a simple and robust solution to overfitting, but it can run into problems.
#
# ![](../assets/validation-error-real.png)
#
# There is debate over how often this problem occurs. You can generally plot both the training and validation loss, see if you're getting multiple optima. If you are, there are multiple suggested techniques to combat this problem in the [paper reference above](http://page.mi.fu-berlin.de/prechelt/Biblio/stop_tricks1997.pdf).

# %%
from tensorflow.keras.callbacks import EarlyStopping

model_es = Sequential()

n_input = X_train.shape[1]

model_es.add(Dense(17, input_dim=n_input, activation='relu'))
model_es.add(Dense(10, activation='relu'))
model_es.add(Dense(1, activation='sigmoid'))

model_es.compile(loss='bce', optimizer='adam', metrics=['acc'])

early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')

history_es = model_es.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=None,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6364 - acc: 0.6591 - val_loss: 0.4959 - val_acc: 0.8058
# Epoch 2/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.4362 - acc: 0.8507 - val_loss: 0.4355 - val_acc: 0.8417
# Epoch 3/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3856 - acc: 0.8579 - val_loss: 0.4055 - val_acc: 0.8489
# Epoch 4/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3557 - acc: 0.8579 - val_loss: 0.3822 - val_acc: 0.8489
# Epoch 5/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3329 - acc: 0.8611 - val_loss: 0.3622 - val_acc: 0.8537
# Epoch 6/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3142 - acc: 0.8703 - val_loss: 0.3457 - val_acc: 0.8561
# Epoch 7/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2960 - acc: 0.8784 - val_loss: 0.3305 - val_acc: 0.8645
# Epoch 8/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2802 - acc: 0.8904 - val_loss: 0.3178 - val_acc: 0.8777
# Epoch 9/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2658 - acc: 0.8968 - val_loss: 0.3052 - val_acc: 0.8813
# Epoch 10/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2537 - acc: 0.9008 - val_loss: 0.2981 - val_acc: 0.8837
# Epoch 11/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2436 - acc: 0.9064 - val_loss: 0.2910 - val_acc: 0.8897
# Epoch 12/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2366 - acc: 0.9160 - val_loss: 0.2870 - val_acc: 0.8945
# Epoch 13/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2295 - acc: 0.9188 - val_loss: 0.2818 - val_acc: 0.8981
# Epoch 14/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2234 - acc: 0.9232 - val_loss: 0.2814 - val_acc: 0.8981
# Epoch 15/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2193 - acc: 0.9224 - val_loss: 0.2746 - val_acc: 0.8981
# Epoch 16/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2158 - acc: 0.9264 - val_loss: 0.2748 - val_acc: 0.8993
# Epoch 17/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2113 - acc: 0.9264 - val_loss: 0.2736 - val_acc: 0.8957
# Epoch 18/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2086 - acc: 0.9300 - val_loss: 0.2702 - val_acc: 0.9029
# Epoch 19/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2047 - acc: 0.9284 - val_loss: 0.2705 - val_acc: 0.9005
# Epoch 20/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2027 - acc: 0.9320 - val_loss: 0.2705 - val_acc: 0.9029
# Epoch 21/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1986 - acc: 0.9324 - val_loss: 0.2692 - val_acc: 0.9053
# Epoch 22/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1963 - acc: 0.9328 - val_loss: 0.2700 - val_acc: 0.9053
# Epoch 23/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1954 - acc: 0.9348 - val_loss: 0.2693 - val_acc: 0.9065
# Epoch 24/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1929 - acc: 0.9360 - val_loss: 0.2678 - val_acc: 0.9041
# Epoch 25/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1903 - acc: 0.9360 - val_loss: 0.2683 - val_acc: 0.9041
# Epoch 26/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1881 - acc: 0.9376 - val_loss: 0.2647 - val_acc: 0.9029
# Epoch 27/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1861 - acc: 0.9388 - val_loss: 0.2644 - val_acc: 0.9041
# Epoch 28/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1848 - acc: 0.9420 - val_loss: 0.2629 - val_acc: 0.9065
# Epoch 29/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1821 - acc: 0.9416 - val_loss: 0.2625 - val_acc: 0.9065
# Epoch 30/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1807 - acc: 0.9448 - val_loss: 0.2637 - val_acc: 0.9041
# Epoch 31/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1787 - acc: 0.9440 - val_loss: 0.2621 - val_acc: 0.9029
# Epoch 32/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1768 - acc: 0.9460 - val_loss: 0.2606 - val_acc: 0.9053
# Epoch 33/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1758 - acc: 0.9456 - val_loss: 0.2604 - val_acc: 0.9053
# Epoch 34/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1737 - acc: 0.9464 - val_loss: 0.2596 - val_acc: 0.9077
# Epoch 35/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1760 - acc: 0.9448 - val_loss: 0.2618 - val_acc: 0.9065
# Epoch 36/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1723 - acc: 0.9460 - val_loss: 0.2638 - val_acc: 0.9065
# Epoch 37/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1703 - acc: 0.9480 - val_loss: 0.2606 - val_acc: 0.9053
# Epoch 38/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1678 - acc: 0.9484 - val_loss: 0.2625 - val_acc: 0.9077
# Epoch 39/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1662 - acc: 0.9480 - val_loss: 0.2634 - val_acc: 0.9077
# Epoch 00039: early stopping

# %%
train_loss_es = history_es.history['loss']
test_loss_es = history_es.history['val_loss']
plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='violet')
plt.plot(test_loss, label='Testing loss', color='lavender')
plt.plot(train_loss_es, label='ES Training loss', color='navy')
plt.plot(test_loss_es, label='ES Testing loss', color='skyblue')
plt.legend();

# %%
history_es.history['acc'][-1], history_es.history['val_acc'][-1]
# Out:
# (0.947979211807251, 0.9076738357543945)

# %%
# Build model using early stopping AND restore_best_weights=True!
# Model
model_es_2 = Sequential()

model_es_2.add(Dense(32, input_shape=(X_train_sc.shape[1],),activation='relu'))
model_es_2.add(Dense(16, activation='relu'))
model_es_2.add(Dense(1, activation='sigmoid'))

# Compile it
model_es_2.compile(loss='bce', optimizer='adam', metrics=['acc'])

early_stop_2= EarlyStopping(patience=5, restore_best_weights=True)

# Fit it
results_es_2 = model_es_2.fit(X_train_sc, y_train, 
                          validation_data=(X_test_sc, y_test),
                         epochs=100, batch_size=256,
                         verbose=0,
                         callbacks=[early_stop_2]) # Add the early stop to the model!

# %%
# Visualize loss
train_loss_es_2 = results_es_2.history['loss']
test_loss_es_2 = results_es_2.history['val_loss']

plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.plot(train_loss_es_2, label='ES Training loss', color='violet')
plt.plot(test_loss_es_2, label='ES Testing loss', color='lavender')
plt.legend();

# %% [markdown]
# ## Keras Resources
# - [Keras EarlyStopping Documentation](https://keras.io/callbacks/#earlystopping)
# - [Keras EarlyStopping Example](http://parneetk.github.io/blog/neural-networks-in-keras/)
#
# ## Tensorflow Resources
# - [Tensorflow.Keras.callbacks.EarlyStopping Documentation](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping)

# %% [markdown]
# # Optimization
# ---
# Now we're going to talk about ways to speed up the process of optimization. Surprisingly, local optima are not often problems with neural networks; there's a much larger issue with "plateaus," or areas where the derivative is approximately 0. This makes learning much slower.
#
# ## Quick Fixes:
# 1. **Feature Scaling:** As we've discussed before, feature scaling can speed up the process of gradient descent. Because gradient descent works "geometrically," the scales of our $w$ values have a large impact on how quickly our parameters converge to the true value. Since we're working with many parameters (often 1,000 or more), scaling our features will speed up optimization.
#
# 2. **Mini-batch Gradient Descent:** In `sklearn`, we use `.fit()` to estimate the parameters in our model. We do the same in neural networks, but if we're working with a very large data set (as is common in neural networks), passing data through our network will cause learning to be slow. By specifying a `batch_size` within the `.fit()` method, we can expedite our learning.
#     - `batch_size`: Integer or `None`. Number of samples per gradient update. If unspecified, it will default to 32.
#
# **Note:** Mini batches will usually be a power of 2 (32, 64, 128, 256, 512) due to the fact that computers operate in base 2.
#
# - [Overview of the three types of gradient descent: batch, stochastic, mini-batch](https://machinelearningmastery.com/gentle-introduction-mini-batch-gradient-descent-configure-batch-size/)

# %% [markdown]
# <a id='momentum'></a>
# ## Gradient Descent with Momentum
#
# One problem we notice with mini-batch gradient descent compared to batch gradient descent is that it tends to oscillate more, due to the fact that at each iteration it is being fed less training data than batch gradient descent.
#
# ![](../assets/grad-descent.png)
# ![](../assets/mini-grad-descent.png)
#
# [*source*](http://pengcheng.tech/2017/09/28/gradient-descent-momentum-and-adam/)
#
# Ideally, we'd like to take advantage of the speed and memory efficiency of mini-batch gradient descent, without the oscillations. We can use the idea of **momentum** to help us out here. (Momentum is based on [exponentially weighted moving averages](https://www.compose.com/articles/metrics-maven-calculating-an-exponentially-weighted-moving-average-in-postgresql/), which causes our oscillations to largely cancel each other out.)
#
# Typically, when updating our parameters, we'll follow this formula:
#
# $$W = W -\alpha\frac{\partial \text{loss}}{\partial W}$$
# $$b = b - \alpha\frac{\partial \text{loss}}{\partial b}$$
#
# We're going to modify this formula to this form:
#
# $$W = W -\alpha V_{\partial W}$$
# $$b = b - \alpha V_{\partial b}$$
#
# Where
# $$V_{\partial W} = \beta V_{\partial W - 1} + (1-\beta)\frac{\partial \text{loss}}{\partial W}$$
# and
# $$V_{\partial b} = \beta V_{\partial b - 1} + (1-\beta)\frac{\partial \text{loss}}{\partial b}$$
#
# When implementing gradient descent with momentum, you'll have two hyperparameters, $\alpha$ and $\beta$. From a practical point of view, $\beta$ is typically $0.9$, but you can test out other values if you'd like.
#
# ### ADAM Optimization
#
# The optimization algorithm you'll likely use when implementing your feed-forward neural network is called ADAM (Adaptive Moment Estimation). It is a combination of gradient descent with momentum and another optimization method called RMSProp (Root Mean Square Propagation). For the sake of this lesson, we won't cover how ADAM works, but with gradient descent with momentum as building block, the ADAM optimization is not too far off, as it largely relies on the concept of momentum.

# %% [markdown]
# ### Data Augmentation
#
# One method of minimizing the risk of overfitting is to gather more data. While this is usually very costly, we may sometimes be able to take our existing data to generate substantially more data.
# - Images: Reflect, crop, random rotations or distortions, adjust lighting.
#     - [The Effectiveness of Data Augmentation in Image Classification using Deep Learning](http://cs231n.stanford.edu/reports/2017/pdfs/300.pdf)
# - Non-Images: [SMOTE](https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/) (Synthetic Minority Over-Sampling Technique)

# %% [markdown]
# <a id='conclusion'></a>
# # Conclusion
#
# Today, we learned about three different methods of regularizing our neural networks: Regularization, dropout, and early stopping.
#
# ## Machine Learning Workflow
#
# As promised, managing bias and variance takes a lot of our attention. If our bias or variance are high, it's likely that our model isn't performing as well as it could.
#
# A workflow for how you should address this (in the context of neural networks and beyond) is as follows:
#
# - Do we have high bias? (i.e. are we performing poorly on our training set?)
#     - If so:
#         - let's build a more complex model / bigger network!
#         - let's consider a new architecture for our neural network!
#         - let's train longer!
# - Do we have high variance? (i.e. are we performing poorly on our test/holdout set?)
#     - If so:
#         - let's gather more data!
#             - Usually very difficult, but we should use "data augmentation" if we can!
#         - let's build a simpler model / smaller network!
#         - let's consider a new architecture for our neural network!
#         - let's regularize!
#     - Once we're satisfied, return to the bias question and repeat.
#
# **Note:** Before deep learning, most tools for handling high bias or high variance adversely affected the other. However, depending on the amount of data we have and how complex our network is, it's often the case that we can drastically reduce variance with out affecting bias.
#
# We also learned about Mini-batch Gradient Descent and Gradient Descent with Momentum. You will almost always work with mini batches. And when optimizing, you will generally use a method called Adam Optimization that is built on a combination of Gradient Descent with Momentum and another optimization technique called RMSProp.
#
# We also briefly discussed data augmentation as a method for increasing our sample sie.
#
# <a id='references'></a>
# ## References and Resources:
#
# - [DeepLearning.ai](https://www.deeplearning.ai/), Andrew Ng's Coursera course on Deep Learning
#   - The videos from this course are on a [YouTube Channel](https://www.youtube.com/channel/UCcIXc5mJsHVYTZR1maL5l9w/featured)
# <br>
# - [Deep Learning Book](http://www.deeplearningbook.org/), textbook written by Ian Goodfellow, creator of Generative Adversarial Networks (GANs)
