# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %matplotlib inline

# %% [markdown]
# ## Load data
# ---
#
# We'll use [Yahoo! Finance](https://finance.yahoo.com/quote/AAPL) to get a few years worth of stock prices from Apple, Inc. (AAPL)

# %%
# Load data

df = pd.read_csv('./datasets/AAPL.csv')

df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-10  187.740005  190.369995  187.649994  190.039993  184.272324
# 1  2018-05-11  189.490005  190.059998  187.449997  188.589996  183.571487
# 2  2018-05-14  189.009995  189.529999  187.860001  188.149994  183.143204
# 3  2018-05-15  186.779999  187.070007  185.100006  186.440002  181.478729
# 4  2018-05-16  186.070007  188.460007  186.000000  188.179993  183.172379
#
#      Volume
# 0  27989300
# 1  26212200
# 2  20778800
# 3  23695200
# 4  19183100

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# Change date column to be datetime dtype

df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %% [markdown]
# ## Set the `Date` column to be the index
# ---
#
# We'll be exploring a few `pandas` methods related to time series data. In order for them to work we need to set the `Date` column to be the index.

# %%
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-05-10  187.740005  190.369995  187.649994  190.039993  184.272324
# 1 2018-05-11  189.490005  190.059998  187.449997  188.589996  183.571487
# 2 2018-05-14  189.009995  189.529999  187.860001  188.149994  183.143204
# 3 2018-05-15  186.779999  187.070007  185.100006  186.440002  181.478729
# 4 2018-05-16  186.070007  188.460007  186.000000  188.179993  183.172379
#
#      Volume
# 0  27989300
# 1  26212200
# 2  20778800
# 3  23695200
# 4  19183100

# %%
# Set Date to be in the index
df.set_index('Date', inplace = True)

df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-10  187.740005  190.369995  187.649994  190.039993  184.272324
# 2018-05-11  189.490005  190.059998  187.449997  188.589996  183.571487
# 2018-05-14  189.009995  189.529999  187.860001  188.149994  183.143204
# 2018-05-15  186.779999  187.070007  185.100006  186.440002  181.478729
# 2018-05-16  186.070007  188.460007  186.000000  188.179993  183.172379
#
#               Volume
# Date
# 2018-05-10  27989300
# 2018-05-11  26212200
# 2018-05-14  20778800
# 2018-05-15  23695200
# 2018-05-16  19183100

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-04  289.170013  293.690002  286.320007  293.160004  292.368561
# 2020-05-05  295.059998  301.000000  294.459991  297.559998  296.756683
# 2020-05-06  300.459991  303.239990  298.869995  300.630005  299.818390
# 2020-05-07  303.220001  305.170013  301.970001  303.739990  302.919983
# 2020-05-08  305.640015  310.350006  304.290009  310.130005  310.130005
#
#               Volume
# Date
# 2020-05-04  33392000
# 2020-05-05  36937800
# 2020-05-06  35583400
# 2020-05-07  28803800
# 2020-05-08  33459600

# %%
# Sort the index
df.sort_index(inplace = True)

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-10  187.740005  190.369995  187.649994  190.039993  184.272324
# 2018-05-11  189.490005  190.059998  187.449997  188.589996  183.571487
# 2018-05-14  189.009995  189.529999  187.860001  188.149994  183.143204
# 2018-05-15  186.779999  187.070007  185.100006  186.440002  181.478729
# 2018-05-16  186.070007  188.460007  186.000000  188.179993  183.172379
#
#               Volume
# Date
# 2018-05-10  27989300
# 2018-05-11  26212200
# 2018-05-14  20778800
# 2018-05-15  23695200
# 2018-05-16  19183100

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-04  289.170013  293.690002  286.320007  293.160004  292.368561
# 2020-05-05  295.059998  301.000000  294.459991  297.559998  296.756683
# 2020-05-06  300.459991  303.239990  298.869995  300.630005  299.818390
# 2020-05-07  303.220001  305.170013  301.970001  303.739990  302.919983
# 2020-05-08  305.640015  310.350006  304.290009  310.130005  310.130005
#
#               Volume
# Date
# 2020-05-04  33392000
# 2020-05-05  36937800
# 2020-05-06  35583400
# 2020-05-07  28803800
# 2020-05-08  33459600

# %% [markdown]
# ## Explore the data
# ---
#
# - `Close`: The price of AAPL when the stock market closes (at 4:30pm ET)
# - `Adj Close`: The closing price, when accounting for dividend payments, stock splits, etc.
# - `High`: The highest price of AAPL during that trading day
# - `Low`: The lowest price of AAPL during that trading day
# - `Open`: The price of AAPL when the stock market opens (at 9:30am ET)
# - `Volume`: How many shares of AAPL were traded that day

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-10  187.740005  190.369995  187.649994  190.039993  184.272324
# 2018-05-11  189.490005  190.059998  187.449997  188.589996  183.571487
# 2018-05-14  189.009995  189.529999  187.860001  188.149994  183.143204
# 2018-05-15  186.779999  187.070007  185.100006  186.440002  181.478729
# 2018-05-16  186.070007  188.460007  186.000000  188.179993  183.172379
#
#               Volume
# Date
# 2018-05-10  27989300
# 2018-05-11  26212200
# 2018-05-14  20778800
# 2018-05-15  23695200
# 2018-05-16  19183100

# %% [markdown]
# ## Filtering by dates
# ---
#
# Now that our `Date` column is the index, we can filter our data in unique ways. Try `df.loc['2018']` in the cell below:

# %%
df.loc['2018']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-10  187.740005  190.369995  187.649994  190.039993  184.272324
# 2018-05-11  189.490005  190.059998  187.449997  188.589996  183.571487
# 2018-05-14  189.009995  189.529999  187.860001  188.149994  183.143204
# 2018-05-15  186.779999  187.070007  185.100006  186.440002  181.478729
# 2018-05-16  186.070007  188.460007  186.000000  188.179993  183.172379
# ...                ...         ...         ...         ...         ...
# 2018-12-24  148.149994  151.550003  146.589996  146.830002  143.924454
# 2018-12-26  148.300003  157.229996  146.720001  157.169998  154.059814
# 2018-12-27  155.839996  156.770004  150.070007  156.149994  153.059998
# 2018-12-28  157.500000  158.520004  154.550003  156.229996  153.138428
# 2018-12-31  158.529999  159.360001  156.479996  157.740005  154.618546
#
#               Volume
# Date
# 2018-05-10  27989300
# 2018-05-11  26212200
# 2018-05-14  20778800
# 2018-05-15  23695200
# 2018-05-16  19183
://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#overview

# %% [markdown]
# ## Rolling
# ---
#
# With time series, we can "roll" statistics across time. For example, the rolling mean is the mean of a moving window across time periods. Pandas offers a variety of methods for creating rolling statistics, which we'll only scratch the surface of here.
#
# The syntax for these can be a little tricky at first. We'll be using a `rolling()` method with a statistical function chained to it.

# %%
df.rolling(3).mean()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-10         NaN         NaN         NaN         NaN         NaN
# 2018-05-11         NaN         NaN         NaN         NaN         NaN
# 2018-05-14  188.746668  189.986664  187.653331  188.926661  183.662338
# 2018-05-15  188.426666  188.886668  186.803335  187.726664  182.731140
# 2018-05-16  187.286667  188.353338  186.320002  187.589996  182.598104
# ...                ...         ...         ...         ...         ...
# 2020-05-04  288.460001  295.740000  286.840006  292.010000  291.221670
# 2020-05-05  290.160004  297.896667  288.876668  293.263336  292.471619
# 2020-05-06  294.896667  299.309997  293.216664  297.116669  296.314545
# 2020-05-07  299.579997  303.136668  298.433329  300.643331  299.831685
# 2020-05-08  303.106669  306.253336  301.710002  304.833333  304.289459
#
#                   Volume
# Date
# 2018-05-10           NaN
# 2018-05-11           NaN
# 2018-05-14  2.499343e+07
# 2018-05-15  2.356207e+07
# 2018-05-16  2.121903e+07
# ...                  ...
# 2020-05-04  4.643740e+07
# 2020-05-05  4.349467e+07
# 2020-05-06  3.530440e+07
# 2020-05-07  3.377500e+07
# 2020-05-08  3.261560e+07
#
# [503 rows x 6 columns]

# %%
df.rolling(10).mean()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-10         NaN         NaN         NaN         NaN         NaN
# 2018-05-11         NaN         NaN         NaN         NaN         NaN
# 2018-05-14         NaN         NaN         NaN         NaN         NaN
# 2018-05-15         NaN         NaN         NaN         NaN         NaN
# 2018-05-16         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2020-05-04  281.994998  286.717001  279.206006  282.798001  282.034540
# 2020-05-05  283.872998  289.092001  282.109006  285.717001  284.945660
# 2020-05-06  286.557999  291.626001  284.776004  288.170001  287.392038
# 2020-05-07  289.292999  293.968002  287.486004  291.041000  290.255286
# 2020-05-08  292.137000  296.702002  290.215005  293.757001  293.047678
#
#                 Volume
# Date
# 2018-05-10         NaN
# 2018-05-11         NaN
# 2018-05-14         NaN
# 2018-05-15         NaN
# 2018-05-16         NaN
# ...                ...
# 2020-05-04  36824850.0
# 2020-05-05  35993840.0
# 2020-05-06  36625750.0
# 2020-05-07  36385770.0
# 2020-05-08  36569010.0
#
# [503 rows x 6 columns]

# %% [markdown]
# ## Challenge
# ---
#
# Plot a line chart with two lines:
# 1. The `Open` price
# 2. The 30 day rolling mean of the `Open` price

# %%
# Sam's Code

plt.figure(figsize=(12,8))
plt.plot(df['Open'],label='actual')
plt.plot(df['Open'].rolling(30).mean(),label='mean')
plt.legend();

# %%
# John's Code

df['Open'].plot()
df['Open'].rolling(30).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Modified John code for median
df['Open'].plot()
df['Open'].rolling(30).median().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## `.diff()`
# ---
# The `.diff()` calculates the difference in a value between a value at time $T$ and that same value at $T-1$. For example, if I have a dataframe of stock prices:
#
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>110</td>
#     </tr>
#   </tbody>
# </table>
#
# <div style="clear: both;"></div>
#
# When I call `.diff()`, I get the following:
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# <div style="clear: both;"></div>

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-10  187.740005  190.369995  187.649994  190.039993  184.272324
# 2018-05-11  189.490005  190.059998  187.449997  188.589996  183.571487
# 2018-05-14  189.009995  189.529999  187.860001  188.149994  183.143204
# 2018-05-15  186.779999  187.070007  185.100006  186.440002  181.478729
# 2018-05-16  186.070007  188.460007  186.000000  188.179993  183.172379
#
#               Volume
# Date
# 2018-05-10  27989300
# 2018-05-11  26212200
# 2018-05-14  20778800
# 2018-05-15  23695200
# 2018-05-16  19183100

# %%
df.diff()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2018-05-10       NaN       NaN       NaN       NaN        NaN         NaN
# 2018-05-11  1.750000 -0.309997 -0.199997 -1.449997  -0.700837  -1777100.0
# 2018-05-14 -0.480010 -0.529999  0.410004 -0.440002  -0.428283  -5433400.0
# 2018-05-15 -2.229996 -2.459992 -2.759995 -1.709992  -1.664475   2916400.0
# 2018-05-16 -0.709992  1.390000  0.899994  1.739991   1.693650  -4512100.0
# ...              ...       ...       ...       ...        ...         ...
# 2020-05-04  2.920013 -5.309998  0.470001  4.089997   4.078949 -26762200.0
# 2020-05-05  5.889985  7.309998  8.139984  4.399994   4.388122   3545800.0
# 2020-05-06  5.399993  2.239990  4.410004  3.070007   3.061707  -1354400.0
# 2020-05-07  2.760010  1.930023  3.100006  3.109985   3.101593  -6779600.0
# 2020-05-08  2.420014  5.179993  2.320008  6.390015   7.210022   4655800.0
#
# [503 rows x 6 columns]

# %%
189.49 - 187.74
# Out:
# 1.75

# %%
189.01 - 187.74
# Out:
# 1.2699999999999818

# %%
df.diff(2)
# Out:
#                  Open      High        Low     Close  Adj Close      Volume
# Date
# 2018-05-10        NaN       NaN        NaN       NaN        NaN         NaN
# 2018-05-11        NaN       NaN        NaN       NaN        NaN         NaN
# 2018-05-14   1.269990 -0.839996   0.210007 -1.889999  -1.129120  -7210500.0
# 2018-05-15  -2.710006 -2.989991  -2.349991 -2.149994  -2.092758  -2517000.0
# 2018-05-16  -2.939988 -1.069992  -1.860001  0.029999   0.029175  -1595700.0
# ...               ...       ...        ...       ...        ...         ...
# 2020-05-04  -0.789978 -0.839997  -2.029999 -0.639984  -0.638275 -12374000.0
# 2020-05-05   8.809998  2.000000   8.609985  8.489991   8.467071 -23216400.0
# 2020-05-06  11.289978  9.549988  12.549988  7.470001   7.449829   2191400.0
# 2020-05-07   8.160003  4.170013   7.510010  6.179992   6.163300  -8134000.0
# 2020-05-08   5.180024  7.110016   5.420014  9.500000  10.311615  -2123800.0
#
# [503 rows x 6 columns]

# %% [markdown]
# ## `.pct_change()`
# ---
#
# `.pct_change()` works similar to `.diff()`, except we're calculating the difference as a change in percentage: $X_{t}/X_{t-1} - 1$
#
# So if I have my table of stock prices:
#
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>110</td>
#     </tr>
#   </tbody>
# </table>
#
# <div style="clear: both;"></div>
#
# The `.pct_change()` will look like this:
#
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>.1</td>
#     </tr>
#   </tbody>
# </table>
#
# <div style="clear: both;"></div>
#
#
# We'd interpret 1-2-2019 as a 10% increase (110/100 - 1 = .10) in price from the day before. Again, the first row is a `NaN` since there is no prior row to calcuate the percent change from.

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-10  187.740005  190.369995  187.649994  190.039993  184.272324
# 2018-05-11  189.490005  190.059998  187.449997  188.589996  183.571487
# 2018-05-14  189.009995  189.529999  187.860001  188.149994  183.143204
# 2018-05-15  186.779999  187.070007  185.100006  186.440002  181.478729
# 2018-05-16  186.070007  188.460007  186.000000  188.179993  183.172379
#
#               Volume
# Date
# 2018-05-10  27989300
# 2018-05-11  26212200
# 2018-05-14  20778800
# 2018-05-15  23695200
# 2018-05-16  19183100

# %%
df.pct_change().head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2018-05-10       NaN       NaN       NaN       NaN        NaN       NaN
# 2018-05-11  0.009321 -0.001628 -0.001066 -0.007630  -0.003803 -0.063492
# 2018-05-14 -0.002533 -0.002789  0.002187 -0.002333  -0.002333 -0.207285
# 2018-05-15 -0.011798 -0.012979 -0.014692 -0.009088  -0.009088  0.140355
# 2018-05-16 -0.003801  0.007430  0.004862  0.009333   0.009332 -0.190423

# %%
(189.49 / 187.74) - 1
# Out:
# 0.00932140193885167

# %% [markdown]
# ## Challenge
# ---
#
# Create three **separate** plots:
# 1. One for the `Close` price
# 2. One for the `Close` price, using `.diff()`
# 3. One for the `Close` price as a percent change.
#
# What happens to your overall data when you diff?

# %%
# John's code

plt.subplot(3,1,1)
df['Close'].plot()
plt.subplot(3,1,2)
df['Close'].diff().plot()
plt.subplot(3,1,3)
df['Close'].pct_change().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# From the solution code

fig, axes = plt.subplots(nrows = 3, figsize = (15, 12))

axes[0].plot(df['Close'])
axes[1].plot(df['Close'].diff())
axes[2].plot(df['Close'].pct_change())

# %% [markdown]
# [Why would we find the difference?](https://otexts.com/fpp2/stationarity.html) Well, there is one assumption that is **required** for nearly every time series model: **stationarity**.
# - If our time series is stationary, then we do not need to difference
# - If our time series is not stationary, then we difference either once (`df.diff()`) or twice (`df.diff().diff()`). Differenced data often is stationary, so we difference our data, then model that!
#
# ## What is stationarity?
# ---
#
# Informally, stationarity means that there **aren't systematic changes in our time series over time**.
# - Our mean stays the same. (There is no trend.)
# - The autocorrelation between $Y_t$ and $Y_{t-k}$ depends only on the size of our lag $k$. (There is no seasonality.)
# - A [white noise process](https://stats.stackexchange.com/questions/7070/what-is-a-white-noise-process) is a common example of a stationary time series.
#
# The problem is, many time series **aren't** stationary.
# - The amount that stock prices vary on a day-to-day basis aren't going to be the same.
# - Crop prices may increase or decrease over time; assuming a constant mean here doesn't make sense.

# %% [markdown]
# ## Shifting
# ---
#
# `df.shift()` is used to bring values from previous dates forward in time.

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-10  187.740005  190.369995  187.649994  190.039993  184.272324
# 2018-05-11  189.490005  190.059998  187.449997  188.589996  183.571487
# 2018-05-14  189.009995  189.529999  187.860001  188.149994  183.143204
# 2018-05-15  186.779999  187.070007  185.100006  186.440002  181.478729
# 2018-05-16  186.070007  188.460007  186.000000  188.179993  183.172379
#
#               Volume
# Date
# 2018-05-10  27989300
# 2018-05-11  26212200
# 2018-05-14  20778800
# 2018-05-15  23695200
# 2018-05-16  19183100

# %%
df.shift().head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-10         NaN         NaN         NaN         NaN         NaN
# 2018-05-11  187.740005  190.369995  187.649994  190.039993  184.272324
# 2018-05-14  189.490005  190.059998  187.449997  188.589996  183.571487
# 2018-05-15  189.009995  189.529999  187.860001  188.149994  183.143204
# 2018-05-16  186.779999  187.070007  185.100006  186.440002  181.478729
#
#                 Volume
# Date
# 2018-05-10         NaN
# 2018-05-11  27989300.0
# 2018-05-14  26212200.0
# 2018-05-15  20778800.0
# 2018-05-16  23695200.0

# %% [markdown]
# ## Creating a simple dataset
# ---
#
# Let's create a simple dataset that tries to predict today's `Close` price using yesterday's `Close` price with today's `Open` price.
#
# **NOTE:** Remember we want stationarity!

# %%
pd.concat([
    df[['Open']].pct_change(),
    df[['Close']].shift().rename(columns = {'Close':'Close_1'}).pct_change(),
    (df[['Close']].pct_change() >= 0).astype(int)
], axis = 1).dropna()
# Out:
#                 Open   Close_1  Close
# Date
# 2018-05-14 -0.002533 -0.007630      0
# 2018-05-15 -0.011798 -0.002333      0
# 2018-05-16 -0.003801 -0.009088      1
# 2018-05-17  0.010372  0.009333      0
# 2018-05-18 -0.004309 -0.006324      0
# ...              ...       ...    ...
# 2020-05-04  0.010201 -0.016099      1
# 2020-05-05  0.020369  0.014149      1
# 2020-05-06  0.018301  0.015009      1
# 2020-05-07  0.009186  0.010317      1
# 2020-05-08  0.007981  0.010345      1
#
# [501 rows x 3 columns]
